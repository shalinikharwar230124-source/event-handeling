# %% [markdown]
# # Dom manipulatin and Event handeling
#
# 1  write code that create a  new paragraph element with the text "Welecome to our website!"and add its to a div with the id "content"on the web page  Explain createElement and appendChild methods do.
# --1 createElement()Method
#     .this methods create a new html element.
#     .in this case it create a new <p> element.
#     .the element is created in memory but it is not yet visible on the webpage until we add it to the Dom
#   2.appendChild()Method
#   . this method add a child element inside a parent element.
#   . here the <p> element is added inside the <div id="content">.
#   .After this step the paragraph become visible on the webpage.

# %%
from IPython.display import HTML
display(HTML("""
<div id="content"></div>
<script>
let paragraph=document.createElement("p");
paragraph.textContent="Welcome to our website!";
document.getElementById("content").appendChild(paragraph);
</script>
"""))
# Out:
# <div id="content"></div>
# <script>
# let paragraph=document.createElement("p");
# paragraph.textContent="Welcome to our website!";
# document.getElementById("content").appendChild(paragraph);
# </script>

# %% [markdown]
# 2 You need to change the appeerance of a button when  users hover  it  Write code that finds a button with id "myButton" and changes its background color to blue and text color  to white using the element .style properly.

# %%
# %%html
# <button id="myButton">Click Me</button>
#
# <script>
#   let button=document.getElementById("myButton");
#   button.addEventListener("mouseover",function(){
#     button.style.backgroundColor="blue";
#     button.style.color="white";
#   });
#   button.addEventListner("mouseout",function(){
#     button.style.backgroundColor="white";
#     button.style.color="black";
#   });
# </script
# Out:
# <button id="myButton">Click Me</button>
#
# <script>
#   let button=document.getElementById("myButton");
#   button.addEventListener("mouseover",function(){
#     button.style.backgroundColor="blue";
#     button.style.color="white";
#   });
#   button.addEventListner("mouseout",function(){
#     button.style.backgroundColor="white";
#     button.style.color="black";
#   });
# </script

# %% [markdown]
# 3 Create a button that shows an alert with the message "Button was clicked" when clicked.also add a second event Listner to the same button that changes it text to "clicked .after being clicked. Explain why EventListner is better then using onclick.

# %%
# %%html
# <button id="clickButton">Click Me</button>
#
# <script>
#   let btn=
#   document.getElementById("clickButton");
#   btn.addEventListner("click",function(){
#     alert("Button was clicked");
#     btn.textContent="Clicked";
#   });
#
#   btn.addEventListner("click",function(){
#     btn.textContent="clicked!"
#   });
# </script>
# Out:
# <button id="clickButton">Click Me</button>
#
# <script>
#   let btn=
#   document.getElementById("clickButton");
#   btn.addEventListner("click",function(){
#     alert("Button was clicked");
#     btn.textContent="Clicked";
#   });
#
#   btn.addEventListner("click",function(){
#     btn.textContent="clicked!"
#   });
# </script>

# %% [markdown]
# --Why addEventListner is better then onclick
# .--with addEventListner ,you can attach multiple function to the same event on the same element
# . More control
# . Keeps HTML and javascript Separete
#
# 4 **Write a function mamed extractDomain that takes an email string like "john@example.com" and returns the domain part("example.com") using only string method do not use regular expression.**

# %%
# %%html
# <script>
#   function extractDomain(email){
#     let atIndex=email.indexOf("@");
#     return email.slice(alIndex+1);
#   }
#
#   let result=extractDomain("john@example.com");
# document.write("domain:"+result);
# </script>
# Out:
# <script>
#   function extractDomain(email){
#     let atIndex=email.indexOf("@");
#     return email.slice(alIndex+1);
#   }
#
#   let result=extractDomain("john@example.com");
# document.write("domain:"+result);
# </script>

# %% [markdown]
# **5  Write a function called repeatMessage that takes a message string and a number  and return the message repeated rhat many times separeted by a space. do not use loop **

# %%
# %%html
# <script>
#   function repeatMessage(message,number){
#     return
#     Array(number).fill(message).join(" ");
#
#     let result=repeatMessage("Hello",3);
#     document.write("result:"+result);
#   }
# </script>
# Out:
# <script>
#   function repeatMessage(message,number){
#     return
#     Array(number).fill(message).join(" ");
#
#     let result=repeatMessage("Hello",3);
#     document.write("result:"+result);
#   }
# </script>

# %% [markdown]
# **6 Explain what the event loop is in javascript and predict the output of the following code. also explain the why the output appears in that specific order
#
# console.log("start");
#
# setTimeut(function(){
#   console.log('Tiimeout 1')
# }0);
#
# console.log('Middle');
#
# setTimeout(function(){
#   console.log('Timeout 2')
# }0);
#
# console.log('End');
#
# --THE Event Loop is mechnanuism in javascript that allows asynchrounous code to run without blocking the main thred.

# %%
# %%html
# <script>
#   console.log('start');
#
#   setTimeout(function(){
#     console.log('Timeout 1');
#   }0);
#
#   console.log('middle');
#   etTimeout(function(){
#     console.log('Timeout 2');
#   }0);
#
#   console.log('End');
#   </script>
# Out:
# <script>
#   console.log('start');
#
#   setTimeout(function(){
#     console.log('Timeout 1');
#   }0);
#
#   console.log('middle');
#   etTimeout(function(){
#     console.log('Timeout 2');
#   }0);
#
#   console.log('End');
#   </script>

# %% [markdown]
# **7  write a java script function named startCoundown that logs "time left X" every second starting from 5 down to 1 and finally logs "Time's up!" use setInterval and clearInterval only**

# %%
# %%html
# <script>
#   function startCoundown(){
#     let count=5;
#
#     let intervalId=setInterval(function(){
#       console.log("Time left"+count);
#       count--;
#       if(count===0){
#         clearInterval(intervalId);
#         console.log("Time's up!");
#       }
#     },1000);
#   }startCoundown();
#   </script>
# Out:
# <script>
#   function startCoundown(){
#     let count=5;
#
#     let intervalId=setInterval(function(){
#       console.log("Time left"+count);
#       count--;
#       if(count===0){
#         clearInterval(intervalId);
#         console.log("Time's up!");
#       }
#     },1000);
#   }startCoundown();
#   </script>

# %% [markdown]
# **8 Expalin what promises are in javascript write code that create a Promise to simulate checking if a user is logged in The promises should resolve with user data after 2 second if successful or reject with an error message  if the user is not found.**
# -- promise in javascript is an object that represent the result of an asynchronous operation
# it has 3 states
# .Pending- operation not finished yet.
# .resolve-operation completed succeessfully.
# Rejected- operation failed.
#
# promise help avoid callback nesting and make asynchrounos code clear.

# %%
# %%html
# <script>
#   function checkLogin(isUserFound){
#     return new Promise(function(resolve,reject){
#       setTimeout(function(){
#         if(isUserFound){
#           resolve({name:"shalini",
#           email:"shalini@email.com"});
#         }else{
#           reject("User not found");
#         }
#       },2000);
#     });
#         }
#         checkLogin(true)
#         .then(function(userData){
#           console.log("user Logged in:",user);
#         })
#         .catch(function(error){
#           console.log("Login failed:",error);
#
#         });
#         </script>
# Out:
# <script>
#   function checkLogin(isUserFound){
#     return new Promise(function(resolve,reject){
#       setTimeout(function(){
#         if(isUserFound){
#           resolve({name:"shalini",
#           email:"shalini@email.com"});
#         }else{
#           reject("User not found");
#         }
#       },2000);
#     });
#         }
#         checkLogin(true)
#         .then(function(userData){
#           console.log("user Logged in:",user);
#         })
#         .catch(function(error){
#           console.log("Login failed:",error);
#
#         });
#         </script>

# %% [markdown]
# **9 Rewrite the following Promise-based code to use async/await syntax. the code fatches user data then fetched that user posts. include proper error handeling**
#
# function getUserDataAndPost(userId){
#   return fetchUserData(userId)
#   .then(userDta=>{
#     return fetchUserPosts(userData.id)
#     .then(posts=>{
#       return{user:userData,posts:posts};
#   });
# })
# .catch(error=>{
#   console.log("Error:", error);;
#   throw error;
# });
# }

# %%
    # %%html
    <script>
      function fetchUserData(userId){
        return new Promise((resolve,reject)=>{
          setTimeout(()=>{
            if(userId===123){
              resolve({name:"shalini",email:"shalini@email.com"});
            }else{
              reject("User not found");
            }

        }1000);
        });
      }
      function fetchUserPosts(userId){
        return new promise((resolve)=>{
          setTimeout(()=>{
            resolve(["post 1","post 2","post 3"]);
          }1000);
        });

      }
      async function getUserDataAndPosts(userId){
        try{
          const userData=await fetchUserData(userId);
          const posts=await fetchUserPosts(userData.id);
          return{user:userData,posts:posts};
        }catch(error){
          console.log("Error:",error);
        }
      }
      getUsreDataAndPost(1);
      </script>
# Out:
# <script>
#   function fetchUserData(userId){
#     return new Promise((resolve,reject)=>{
#       setTimeout(()=>{
#         if(userId===123){
#           resolve({name:"shalini",email:"shalini@email.com"});
#         }else{
#           reject("User not found");
#         }
#
#     }1000);
#     });
#   }
#   function fetchUserPosts(userId){
#     return new promise((resolve)=>{
#       setTimeout(()=>{
#         resolve(["post 1","post 2","post 3"]);
#       }1000);
#     });
#
#   }
#   async function getUserDataAndPosts(userId){
#     try{
#       const userData=await fetchUserData(userId);
#       const posts=await fetchUserPosts(userData.id);
#       return{user:userData,posts:posts};
#     }catch(error){
#       console.log("Error:",error);
#     }
#   }
#   getUsreDataAndPost(1);
#   </script>

# %% [markdown]
# **10  write code using fetch API to get weather  data from  a public API  display the weather information in a userfriendly ,format assume you hav ethe following configuration for the API**
# ** const apikey='abcd1234';
# const apiUrl=https://api.openweathermap.org/data/2.5/weather?q=Munbai&appid=${apKey}&units=metric;
#
# -- the fetch() API is used to make HTTP request it retyrn a promise

# %%
# %%javascript
# const fetch=require("node-fetch");
#
# const apikey='abcd1234';
# const apiUrl=`https://api.openweathermap.org/data/2.5/weather?q=Mumbai&appid=${apikey}&units=metric`;
#
# fetch (apiUrl)
# .then(response=>response.json())
# .then(data=>{
#   const weather=data.weather:[0].description;
#   const temperature=data.main.temp;
#   console.log("Weather:",
#   data.weather[0].description);
#   console.log("Temperature:",data.main.temp);
# })
# .catch(error=>console.error("Error:",error));
# </script>
#
#
# fetch(apiUrl)
